# %% [markdown]
# # データを確認する
#
# - csvデータをDataFrame化して、特徴を把握する
# - 分析の方針を立てる
# - データの加工方法を決定し、分析用のDataFrameを作成する

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from datetime import datetime

# %% [markdown]
# ## air_reserve.csv [Airリザーブの予約データ]
#
# - 92,378レコード
# - 314 /829店舗分の予約データ
# - 訪問予定は、2016-01-01 19:00:00 〜 2017-05-31 21:00:00
# - 予約時刻は、2016-01-01 01:00:00 〜 2017-04-22 23:00:00

# %%
# .csvをDataFrame化
df1 = pd.read_csv('Data/csv/air_reserve.csv')
df1.head()
# Out:
#            air_store_id       visit_datetime     reserve_datetime  \
# 0  air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1  air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2  air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3  air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4  air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
#
#    reserve_visitors
# 0                 1
# 1                 3
# 2                 6
# 3                 2
# 4                 5

# %%
# データ型を確認
df1.dtypes
# Out:
# air_store_id        object
# visit_datetime      object
# reserve_datetime    object
# reserve_visitors     int64
# dtype: object

# %%
# データ型を修正
df1['visit_datetime'] = df1.visit_datetime.map(lambda x: datetime.strptime(x,'%Y-%m-%d %H:%M:%S'))
df1['reserve_datetime'] = df1.reserve_datetime.map(lambda x: datetime.strptime(x,'%Y-%m-%d %H:%M:%S'))
df1.dtypes
# Out:
# air_store_id                object
# visit_datetime      datetime64[ns]
# reserve_datetime    datetime64[ns]
# reserve_visitors             int64
# dtype: object

# %%
# 統計量を確認
df1.describe()
# Out:
#        reserve_visitors
# count      92378.000000
# mean           4.481749
# std            4.919669
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            5.000000
# max          100.000000

# %%
# air_store_idのユニーク数
df1_id = df1.air_store_id.value_counts().count()
# visit_datetimeの最大・最小値
df1_min_vdate = df1.visit_datetime.min()
df1_max_vdate = df1.visit_datetime.max()
# reserve_datetimeの最大・最小値
df1_min_rdate = df1.reserve_datetime.min()
df1_max_rdate = df1.reserve_datetime.max()
print(df1_id,df1_min_vdate,df1_max_vdate,df1_min_rdate,df1_max_rdate)
# Out:
# 314 2016-01-01 19:00:00 2017-05-31 21:00:00 2016-01-01 01:00:00 2017-04-22 23:00:00

# %%
# describeのoptionで上記も確認可能だった。https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html
df1.describe(include='all')
# Out:
#                 air_store_id       visit_datetime     reserve_datetime  \
# count                  92378                92378                92378
# unique                   314                 4975                 7513
# top     air_8093d0b565e9dbdf  2016-12-24 19:00:00  2016-11-24 18:00:00
# freq                    2263                  255                  106
# first                    NaN  2016-01-01 19:00:00  2016-01-01 01:00:00
# last                     NaN  2017-05-31 21:00:00  2017-04-22 23:00:00
# mean                     NaN                  NaN                  NaN
# std                      NaN                  NaN                  NaN
# min                      NaN                  NaN                  NaN
# 25%                      NaN                  NaN                  NaN
# 50%                      NaN                  NaN                  NaN
# 75%                      NaN                  NaN                  NaN
# max                      NaN                  NaN                  NaN
#
#         reserve_visitors
# count       92378.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# first                NaN
# last                 NaN
# mean            4.481749
# std             4.919669
# min             1.000000
# 25%             2.000000
# 50%             3.000000
# 75%             5.000000
# max           100.000000

# %% [markdown]
# ## air_store_info.csv [Airリザーブのレストラン情報]
#
# - 829店舗
# - 14ジャンル
# - 103エリア

# %%
# .csvをDataFrame化
df2 = pd.read_csv('Data/csv/air_store_info.csv')
df2.head()
# Out:
#            air_store_id  air_genre_name                 air_area_name  \
# 0  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 1  air_7cc17a324ae5c7dc  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 2  air_fee8dcf4d619598e  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 3  air_a17f0778617c76e2  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 4  air_83db5aff8f50478e  Italian/French  Tōkyō-to Minato-ku Shibakōen
#
#     latitude   longitude
# 0  34.695124  135.197852
# 1  34.695124  135.197852
# 2  34.695124  135.197852
# 3  34.695124  135.197852
# 4  35.658068  139.751599

# %%
# データ型を確認
df2.dtypes
# Out:
# air_store_id       object
# air_genre_name     object
# air_area_name      object
# latitude          float64
# longitude         float64
# dtype: object

# %%
# 統計量を確認
df2.describe(include='all')
# Out:
#                 air_store_id air_genre_name                   air_area_name  \
# count                    829            829                             829
# unique                   829             14                             103
# top     air_3bb99a1fe0583897        Izakaya  Fukuoka-ken Fukuoka-shi Daimyō
# freq                       1            197                              64
# mean                     NaN            NaN                             NaN
# std                      NaN            NaN                             NaN
# min                      NaN            NaN                             NaN
# 25%                      NaN            NaN                             NaN
# 50%                      NaN            NaN                             NaN
# 75%                      NaN            NaN                             NaN
# max                      NaN            NaN                             NaN
#
#           latitude   longitude
# count   829.000000  829.000000
# unique         NaN         NaN
# top            NaN         NaN
# freq           NaN         NaN
# mean     35.647042  137.415311
# std       2.084659    3.650971
# min      33.211967  130.195555
# 25%      34.695124  135.341564
# 50%      35.658068  139.685474
# 75%      35.694003  139.751599
# max      44.020632  144.273398

# %%
# 上記で確認できるため不要に
# df2_genre = df2.air_genre_name.value_counts().count()
# df2_area = df2.air_area_name.value_counts().count()
# print(df2_genre,df2_area)

# %%
# ジャンルの内訳と頻度
df2.groupby('air_genre_name').size().sort_values(ascending=False)
# Out:
# air_genre_name
# Izakaya                         197
# Cafe/Sweets                     181
# Dining bar                      108
# Italian/French                  102
# Bar/Cocktail                     79
# Japanese food                    63
# Other                            27
# Yakiniku/Korean food             23
# Western food                     16
# Okonomiyaki/Monja/Teppanyaki     14
# Creative cuisine                 13
# Karaoke/Party                     2
# International cuisine             2
# Asian                             2
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df2_air_genre_name = df2.groupby('air_genre_name').size().sort_values()
plt.barh(np.arange(1,15), df2_air_genre_name.values, tick_label=df2_air_genre_name.index, align="center")
plt.title("air_genre_freq")
plt.xlabel("frequency")
plt.ylabel("genre")
plt.grid(True)

# %%
# エリアの内訳と頻度
df2.groupby('air_area_name').size().sort_values(ascending=False).head(15)
# Out:
# air_area_name
# Fukuoka-ken Fukuoka-shi Daimyō                64
# Tōkyō-to Shibuya-ku Shibuya                   58
# Tōkyō-to Minato-ku Shibakōen                  51
# Tōkyō-to Shinjuku-ku Kabukichō                39
# Tōkyō-to Setagaya-ku Setagaya                 30
# Tōkyō-to Chūō-ku Tsukiji                      29
# Ōsaka-fu Ōsaka-shi Ōgimachi                   25
# Hiroshima-ken Hiroshima-shi Kokutaijimachi    23
# Tōkyō-to Meguro-ku Kamimeguro                 22
# Tōkyō-to Suginami-ku Asagayaminami            21
# Hokkaidō Sapporo-shi Minami 3 Jōnishi         21
# Tōkyō-to Chiyoda-ku Kudanminami               20
# Ōsaka-fu Ōsaka-shi Kyūtarōmachi               19
# Hyōgo-ken Kōbe-shi Kumoidōri                  17
# Miyagi-ken Sendai-shi Kamisugi                17
# dtype: int64

# %%
# エリアを市区町村レベルに変更、plot時の文字化け対策で置換
df2_edit = df2.copy()
df2_edit['air_area_name'] = df2_edit.air_area_name.map(lambda x: ' '.join(x.split(' ')[:2]).translate(str.maketrans('Ōōū', 'Oou')))
df2_edit.head()
# Out:
#            air_store_id  air_genre_name       air_area_name   latitude  \
# 0  air_0f0cdeee6c9bf3d7  Italian/French  Hyogo-ken Kobe-shi  34.695124
# 1  air_7cc17a324ae5c7dc  Italian/French  Hyogo-ken Kobe-shi  34.695124
# 2  air_fee8dcf4d619598e  Italian/French  Hyogo-ken Kobe-shi  34.695124
# 3  air_a17f0778617c76e2  Italian/French  Hyogo-ken Kobe-shi  34.695124
# 4  air_83db5aff8f50478e  Italian/French  Tokyo-to Minato-ku  35.658068
#
#     longitude
# 0  135.197852
# 1  135.197852
# 2  135.197852
# 3  135.197852
# 4  139.751599

# %%
df2_edit.air_area_name.describe()
# Out:
# count                         829
# unique                         55
# top       Fukuoka-ken Fukuoka-shi
# freq                          103
# Name: air_area_name, dtype: object

# %%
df2_air_area_name = df2_edit.groupby('air_area_name').size().sort_values()
plt.figure(figsize=(12, 14))
plt.barh(np.arange(1,56), df2_air_area_name.values, tick_label=df2_air_area_name.index, align="center")
plt.title("air_genre_freq")
plt.xlabel("frequency")
plt.ylabel("genre")
plt.grid(True)

# %% [markdown]
# ## air_visit_data.csv [Airリザーブの訪問データ]
#
# - 252,108レコード
# - 829店舗全ての履歴データがある
# - 訪問日時は、2016-01-01 〜 2017-04-22

# %%
# .csvをDataFrame化
df3 = pd.read_csv('Data/csv/air_visit_data.csv')
df3.head()
# Out:
#            air_store_id  visit_date  visitors
# 0  air_ba937bf13d40fb24  2016-01-13        25
# 1  air_ba937bf13d40fb24  2016-01-14        32
# 2  air_ba937bf13d40fb24  2016-01-15        29
# 3  air_ba937bf13d40fb24  2016-01-16        22
# 4  air_ba937bf13d40fb24  2016-01-18         6

# %%
# データ型を確認
df3.dtypes
# Out:
# air_store_id    object
# visit_date      object
# visitors         int64
# dtype: object

# %%
# データ型を修正
df3['visit_date'] = df3.visit_date.map(lambda x: datetime.strptime(x,'%Y-%m-%d'))
df3.dtypes
# Out:
# air_store_id            object
# visit_date      datetime64[ns]
# visitors                 int64
# dtype: object

# %%
# 統計量を確認
df3.describe(include='all')
# Out:
#                 air_store_id           visit_date       visitors
# count                 252108               252108  252108.000000
# unique                   829                  478            NaN
# top     air_5c817ef28f236bdf  2017-03-17 00:00:00            NaN
# freq                     477                  799            NaN
# first                    NaN  2016-01-01 00:00:00            NaN
# last                     NaN  2017-04-22 00:00:00            NaN
# mean                     NaN                  NaN      20.973761
# std                      NaN                  NaN      16.757007
# min                      NaN                  NaN       1.000000
# 25%                      NaN                  NaN       9.000000
# 50%                      NaN                  NaN      17.000000
# 75%                      NaN                  NaN      29.000000
# max                      NaN                  NaN     877.000000

# %%
# 上記で確認できるため不要に
# df3_id = df3.air_store_id.value_counts().count()
# df3_min_vdate = df3.visit_date.min()
# df3_max_vdate = df3.visit_date.max()
# print(df3_id,df3_min_vdate,df3_max_vdate)

# %% [markdown]
# ## hpg_reserve.csv [ホットペッパーグルメの予約データ]
#
# - 2,000,320レコード
# - 13,325 /4,690店舗の予約データ???
# - 訪問予定は、2016-01-01 11:00:00 〜 2017-05-31 23:00:00
# - 予約時刻は、2016-01-01 00:00:00 〜 2017-04-22 23:00:00

# %%
df4 = pd.read_csv('Data/csv/hpg_reserve.csv')
df4.head()
# Out:
#            hpg_store_id       visit_datetime     reserve_datetime  \
# 0  hpg_c63f6f42e088e50f  2016-01-01 11:00:00  2016-01-01 09:00:00
# 1  hpg_dac72789163a3f47  2016-01-01 13:00:00  2016-01-01 06:00:00
# 2  hpg_c8e24dcf51ca1eb5  2016-01-01 16:00:00  2016-01-01 14:00:00
# 3  hpg_24bb207e5fd49d4a  2016-01-01 17:00:00  2016-01-01 11:00:00
# 4  hpg_25291c542ebb3bc2  2016-01-01 17:00:00  2016-01-01 03:00:00
#
#    reserve_visitors
# 0                 1
# 1                 3
# 2                 2
# 3                 5
# 4                13

# %%
df4.describe()
# Out:
#        reserve_visitors
# count      2.000320e+06
# mean       5.073785e+00
# std        5.416172e+00
# min        1.000000e+00
# 25%        2.000000e+00
# 50%        3.000000e+00
# 75%        6.000000e+00
# max        1.000000e+02

# %%
df4_records = df4.hpg_store_id.count()
df4_id = df4.hpg_store_id.value_counts().count()
df4_min_vdate = df4.visit_datetime.min()
df4_max_vdate = df4.visit_datetime.max()
df4_min_rdate = df4.reserve_datetime.min()
df4_max_rdate = df4.reserve_datetime.max()
print(df4_records,df4_id,df4_min_vdate,df4_max_vdate,df4_min_rdate,df4_max_rdate)
# Out:
# 2000320 13325 2016-01-01 11:00:00 2017-05-31 23:00:00 2016-01-01 00:00:00 2017-04-22 23:00:00

# %% [markdown]
# ## hpg_store_info.csv [ホットペッパーグルメのレストラン情報]
#
# - 4,690の店舗データ
# - 34ジャンル
# - 119エリア

# %%
df5 = pd.read_csv('Data/csv/hpg_store_info.csv')
df5.head()
# Out:
#            hpg_store_id  hpg_genre_name                  hpg_area_name  \
# 0  hpg_6622b62385aec8bf  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 1  hpg_e9e068dd49c5fa00  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 2  hpg_2976f7acb4b3a3bc  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 3  hpg_e51a522e098f024c  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 4  hpg_e3d0e1519894f275  Japanese style  Tōkyō-to Setagaya-ku Taishidō
#
#     latitude   longitude
# 0  35.643675  139.668221
# 1  35.643675  139.668221
# 2  35.643675  139.668221
# 3  35.643675  139.668221
# 4  35.643675  139.668221

# %%
df5.describe()
# Out:
#           latitude    longitude
# count  4690.000000  4690.000000
# mean     35.810261   137.675816
# std       2.138755     3.197233
# min      33.311645   130.339313
# 25%      34.692109   135.498859
# 50%      35.659214   139.495733
# 75%      35.703381   139.737998
# max      43.774846   143.714585

# %%
df5_id = df5.hpg_store_id.value_counts().count()
df5_genre = df5.hpg_genre_name.value_counts().count()
df5_area = df5.hpg_area_name.value_counts().count()
print(df5_id,df5_genre,df5_area)
# Out:
# 4690 34 119

# %%
df5.groupby('hpg_genre_name').size()
# Out:
# hpg_genre_name
# Amusement bar                      5
# Bar/Cocktail                       7
# Bistro                            22
# Cafe                              16
# Cantonese food                     4
# Chinese general                   91
# Creation                         410
# Creative Japanese food            60
# Dim Sum/Dumplings                  2
# French                            27
# Grilled meat                     325
# International cuisine            700
# Italian                          249
# Japanese cuisine/Kaiseki          64
# Japanese food in general          85
# Japanese style                  1750
# Karaoke                           60
# Korean cuisine                    38
# Okonomiyaki/Monja/Teppanyaki      44
# Party                             40
# Pasta/Pizza                       10
# Seafood                          339
# Shabu-shabu/Sukiyaki              59
# Shanghai food                      1
# Sichuan food                       3
# Spain Bar/Italian Bar            229
# Spain/Mediterranean cuisine        1
# Steak/Hamburger/Curry             24
# Sushi                             11
# Sweets                             2
# Taiwanese/Hong Kong cuisine        1
# Thai/Vietnamese food               5
# Udon/Soba                          1
# Western food                       5
# dtype: int64

# %%
df5.groupby('hpg_area_name').size()
# Out:
# hpg_area_name
# Fukuoka-ken Chikushino-shi Yamaguchi                               5
# Fukuoka-ken Fukuoka-shi Daimyō                                    50
# Fukuoka-ken Fukuoka-shi Hakata Ekimae                             66
# Fukuoka-ken Fukuoka-shi Matsushima                                 3
# Fukuoka-ken Fukuoka-shi Minamishō                                 22
# Fukuoka-ken Fukuoka-shi None                                      90
# Fukuoka-ken Fukuoka-shi Ōmiya                                     26
# Fukuoka-ken Iizuka-shi Mashiki                                     2
# Fukuoka-ken Kitakyūshū-shi Aoyama                                 19
# Fukuoka-ken Kitakyūshū-shi Sunatsu                                65
# Fukuoka-ken Kurume-shi Higashimachi                               32
# Hiroshima-ken Fukuyama-shi Sannomaruchō                           40
# Hiroshima-ken Higashihiroshima-shi Hachihonmatsuchō Yoshikawa     10
# Hiroshima-ken Hiroshima-shi Hondōri                              135
# Hiroshima-ken Hiroshima-shi Yokogawachō                           60
# Hokkaidō Asahikawa-shi 3 Jōdōri                                   41
# Hokkaidō Asahikawa-shi Higashi 6 Jō                                4
# Hokkaidō Ashibetsu-shi None                                        1
# Hokkaidō Hakodate-shi None                                        17
# Hokkaidō Sapporo-shi Hondōri (Kita)                               13
# Hokkaidō Sapporo-shi Kita 30 Jōhigashi                             9
# Hokkaidō Sapporo-shi Minami 4 Jōnishi                            110
# Hokkaidō Sapporo-shi None                                         84
# Hokkaidō Sapporo-shi Sumikawa 2 Jō                                 5
# Hokkaidō Tokachi-gun Kawakami                                     14
# Hyōgo-ken Akashi-shi Nishiakashichō                               22
# Hyōgo-ken Amagasaki-shi Minamitsukaguchichō                       17
# Hyōgo-ken Himeji-shi Tsuchiyama                                   63
# Hyōgo-ken Kakogawa-shi Noguchichō Yoshino                         28
# Hyōgo-ken Kōbe-shi Mikage Nakamachi                               10
#                                                                 ...
# Tōkyō-to Shibuya-ku Ebisunishi                                    58
# Tōkyō-to Shibuya-ku None                                         127
# Tōkyō-to Shinagawa-ku Koyama                                       1
# Tōkyō-to Shinagawa-ku Yutakachō                                   16
# Tōkyō-to Shinjuku-ku Hyakuninchō                                  21
# Tōkyō-to Shinjuku-ku None                                        257
# Tōkyō-to Shinjuku-ku Takadanobaba                                 16
# Tōkyō-to Suginami-ku Izumi                                         9
# Tōkyō-to Sumida-ku Tachibana                                      86
# Tōkyō-to Taitō-ku None                                           100
# Tōkyō-to Tama-shi Tsurumaki                                       11
# Tōkyō-to Toshima-ku Kitaōtsuka                                    18
# Tōkyō-to Toshima-ku None                                         119
# Ōsaka-fu Higashiōsaka-shi Wakaenishishinmachi                     29
# Ōsaka-fu Ibaraki-shi Shimochūjōchō                                 9
# Ōsaka-fu Kaizuka-shi Umizuka                                      11
# Ōsaka-fu Minoo-shi Hanjo                                           1
# Ōsaka-fu Neyagawa-shi Kotobukichō                                 26
# Ōsaka-fu Sakai-shi Kobirao                                         2
# Ōsaka-fu Sakai-shi None                                           58
# Ōsaka-fu Suita-shi Enokichō                                       43
# Ōsaka-fu Takatsuki-shi Kamitanabechō                              20
# Ōsaka-fu Ōsaka-shi Abenosuji                                      28
# Ōsaka-fu Ōsaka-shi Awajimachi                                     66
# Ōsaka-fu Ōsaka-shi Hannanchō                                       5
# Ōsaka-fu Ōsaka-shi Izuo                                            5
# Ōsaka-fu Ōsaka-shi Nakanochō                                      35
# Ōsaka-fu Ōsaka-shi None                                           16
# Ōsaka-fu Ōsaka-shi Shinsaibashisuji                              150
# Ōsaka-fu Ōsaka-shi Tsuruhashi                                     10
# dtype: int64

# %% [markdown]
# ## date_info.csv [カレンダー]
#
# - 2016-01-01〜2017-05-31

# %%
df6 = pd.read_csv('Data/csv/date_info.csv')
df6.head()
# Out:
#   calendar_date day_of_week  holiday_flg
# 0    2016-01-01      Friday            1
# 1    2016-01-02    Saturday            1
# 2    2016-01-03      Sunday            1
# 3    2016-01-04      Monday            0
# 4    2016-01-05     Tuesday            0

# %%
df6_min_date = df6.calendar_date.min()
df6_max_date = df6.calendar_date.max()
print(df6_min_date,df6_max_date)
# Out:
# 2016-01-01 2017-05-31

# %% [markdown]
# ## store_id_relation.csv [id横断データ]
#
# - 150店舗、１対１

# %%
df7 = pd.read_csv('Data/csv/store_id_relation.csv')
df7.head()
# Out:
#            air_store_id          hpg_store_id
# 0  air_63b13c56b7201bd9  hpg_4bc649e72e2a239a
# 1  air_a24bf50c3e90d583  hpg_c34b496d0305a809
# 2  air_c7f78b4f3cba33ff  hpg_cd8ae0d9bbd58ff9
# 3  air_947eb2cae4f3e8f2  hpg_de24ea49dc25d6b8
# 4  air_965b2e0cf4119003  hpg_653238a84804d8e7

# %%
df7.describe()
# Out:
#                 air_store_id          hpg_store_id
# count                    150                   150
# unique                   150                   150
# top     air_324f7c39a8410e7c  hpg_aa7dfdc68a0a879c
# freq                       1                     1

# %% [markdown]
# ## sample_submission.csv [Submitサンプル]
#
# - store_idに、アンダースコア、訪問日を付与する必要がある
# - 2017-04-23〜2017-05-31が予測対象期間
# - visitorsに予測値を出力する

# %%
sample = pd.read_csv('Data/csv/sample_submission.csv')
sample.head()
# Out:
#                                 id  visitors
# 0  air_00a91d42b08b08d9_2017-04-23         0
# 1  air_00a91d42b08b08d9_2017-04-24         0
# 2  air_00a91d42b08b08d9_2017-04-25         0
# 3  air_00a91d42b08b08d9_2017-04-26         0
# 4  air_00a91d42b08b08d9_2017-04-27         0

# %%
sample['air_store_id'] = sample.id.map(lambda x: '_'.join(x.split('_')[:-1]))
sample['calendar_date'] = sample.id.map(lambda x: x.split('_')[2])
sample.drop('id',axis=1)
sample.loc[:,['air_store_id','calendar_date','visitors']].head()
# Out:
#            air_store_id calendar_date  visitors
# 0  air_00a91d42b08b08d9    2017-04-23         0
# 1  air_00a91d42b08b08d9    2017-04-24         0
# 2  air_00a91d42b08b08d9    2017-04-25         0
# 3  air_00a91d42b08b08d9    2017-04-26         0
# 4  air_00a91d42b08b08d9    2017-04-27         0

# %% [markdown]
# ### メモ
# - 大口の予約レコードの取り扱い方法
# - 予約に対する実訪問データの状況
# - ジャンルのマッピングが必要そう
# - 2016年4,5月の実績が重要。それ以外の期間の重み付けを下げる方法はあるのか...?
#
# - 天候 [予測対象期間が過去のため]
# - 歓迎会シーズン
# - オフィス数、住宅数 [都市では活きないか？]
# - イベント[祭りなど]
# - 人口
# - 飲食店の数

# %% [markdown]
# # 訪問数に対する予約率を見てみる

# %%
df1.head()
# Out:
#            air_store_id       visit_datetime     reserve_datetime  \
# 0  air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1  air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2  air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3  air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4  air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
#
#    reserve_visitors
# 0                 1
# 1                 3
# 2                 6
# 3                 2
# 4                 5

# %%
df1['visit_datetime'] = df1['visit_datetime'].str[:10]
df1.head()
# Out:
#            air_store_id visit_datetime     reserve_datetime  reserve_visitors
# 0  air_877f79706adbfb06     2016-01-01  2016-01-01 16:00:00                 1
# 1  air_db4b38ebe7a7ceff     2016-01-01  2016-01-01 19:00:00                 3
# 2  air_db4b38ebe7a7ceff     2016-01-01  2016-01-01 19:00:00                 6
# 3  air_877f79706adbfb06     2016-01-01  2016-01-01 16:00:00                 2
# 4  air_db80363d35f10926     2016-01-01  2016-01-01 01:00:00                 5

# %%
df1_edit = df1.rename(columns={'visit_datetime': 'visit_date'}).drop('reserve_datetime',axis=1)
df1_edit = df1_edit.groupby(['air_store_id','visit_date'])['reserve_visitors'].sum().reset_index()
df1_edit.head()
# Out:
#            air_store_id  visit_date  reserve_visitors
# 0  air_00a91d42b08b08d9  2016-10-31                 2
# 1  air_00a91d42b08b08d9  2016-12-05                 9
# 2  air_00a91d42b08b08d9  2016-12-14                18
# 3  air_00a91d42b08b08d9  2016-12-17                 2
# 4  air_00a91d42b08b08d9  2016-12-20                 4

# %%
df3.head()
# Out:
#            air_store_id  visit_date  visitors
# 0  air_ba937bf13d40fb24  2016-01-13        25
# 1  air_ba937bf13d40fb24  2016-01-14        32
# 2  air_ba937bf13d40fb24  2016-01-15        29
# 3  air_ba937bf13d40fb24  2016-01-16        22
# 4  air_ba937bf13d40fb24  2016-01-18         6

# %%
air_df = pd.merge(df3,df1_edit,on=['air_store_id','visit_date'],how='left')
air_df.head()
# Out:
#            air_store_id  visit_date  visitors  reserve_visitors
# 0  air_ba937bf13d40fb24  2016-01-13        25               NaN
# 1  air_ba937bf13d40fb24  2016-01-14        32               NaN
# 2  air_ba937bf13d40fb24  2016-01-15        29               NaN
# 3  air_ba937bf13d40fb24  2016-01-16        22               NaN
# 4  air_ba937bf13d40fb24  2016-01-18         6               NaN

# %%
air_df.columns
# Out:
# Index(['air_store_id', 'visit_date', 'visitors', 'reserve_visitors'], dtype='object')

# %%
air_df = DataFrame(air_df, columns=['air_store_id','visit_date','visitors','reserve_visitors','reserve_rate'])
air_df['reserve_rate'] = air_df['reserve_visitors'] / air_df['visitors'] * 100
air_df.head()
# Out:
#            air_store_id  visit_date  visitors  reserve_visitors  reserve_rate
# 0  air_ba937bf13d40fb24  2016-01-13        25               NaN           NaN
# 1  air_ba937bf13d40fb24  2016-01-14        32               NaN           NaN
# 2  air_ba937bf13d40fb24  2016-01-15        29               NaN           NaN
# 3  air_ba937bf13d40fb24  2016-01-16        22               NaN           NaN
# 4  air_ba937bf13d40fb24  2016-01-18         6               NaN           NaN

# %%
air_df[air_df['reserve_rate'] > 0]
# Out:
#                 air_store_id  visit_date  visitors  reserve_visitors  \
# 1006    air_35512c42db0868da  2016-02-27         6              12.0
# 3744    air_ee3a01f0c71a769f  2016-01-04        61               2.0
# 3747    air_ee3a01f0c71a769f  2016-01-08        21               3.0
# 3748    air_ee3a01f0c71a769f  2016-01-09        57              25.0
# 3749    air_ee3a01f0c71a769f  2016-01-10        32               5.0
# 3750    air_ee3a01f0c71a769f  2016-01-11        35               6.0
# 3754    air_ee3a01f0c71a769f  2016-01-16        34               6.0
# 3755    air_ee3a01f0c71a769f  2016-01-17        58              12.0
# 3756    air_ee3a01f0c71a769f  2016-01-18        14               2.0
# 3758    air_ee3a01f0c71a769f  2016-01-22         6               1.0
# 3759    air_ee3a01f0c71a769f  2016-01-23        34              15.0
# 3760    air_ee3a01f0c71a769f  2016-01-24        64              21.0
# 3761    air_ee3a01f0c71a769f  2016-01-25        23               2.0
# 3765    air_ee3a01f0c71a769f  2016-01-30        53               9.0
# 3766    air_ee3a01f0c71a769f  2016-01-31        58              20.0
# 3767    air_ee3a01f0c71a769f  2016-02-01        24               2.0
# 3770    air_ee3a01f0c71a769f  2016-02-06        65              18.0
# 3771    air_ee3a01f0c71a769f  2016-02-07        67              19.0
# 3775    air_ee3a01f0c71a769f  2016-02-11        37               9.0
# 3776    air_ee3a01f0c71a769f  2016-02-13        55              19.0
# 3777    air_ee3a01f0c71a769f  2016-02-14        63              24.0
# 3782    air_ee3a01f0c71a769f  2016-02-20        47               8.0
# 3784    air_ee3a01f0c71a769f  2016-02-22        38               4.0
# 3785    air_ee3a01f0c71a769f  2016-02-23        30              13.0
# 3786    air_ee3a01f0c71a769f  2016-02-24        39               2.0
# 3787    air_ee3a01f0c71a769f  2016-02-26        14               2.0
# 3788    air_ee3a01f0c71a769f  2016-02-27        58              45.0
# 3789    air_ee3a01f0c71a769f  2016-02-28        66              35.0
# 3794    air_ee3a01f0c71a769f  2016-03-05        57              21.0
# 3795    air_ee3a01f0c71a769f  2016-03-06        50              11.0
# ...                      ...         ...       ...               ...
# 248996  air_754ae581ad80cc9f  2017-02-16        36              16.0
# 248997  air_754ae581ad80cc9f  2017-02-17        13               8.0
# 248998  air_754ae581ad80cc9f  2017-02-18        32              11.0
# 248999  air_754ae581ad80cc9f  2017-02-19        32              18.0
# 249001  air_754ae581ad80cc9f  2017-02-22        10               8.0
# 249005  air_754ae581ad80cc9f  2017-02-26        27               4.0
# 249006  air_754ae581ad80cc9f  2017-02-27        20               4.0
# 249009  air_754ae581ad80cc9f  2017-03-02         1              11.0
# 249010  air_754ae581ad80cc9f  2017-03-03        35              22.0
# 249011  air_754ae581ad80cc9f  2017-03-04        15               5.0
# 249012  air_754ae581ad80cc9f  2017-03-05        10               5.0
# 249016  air_754ae581ad80cc9f  2017-03-09        10               6.0
# 249017  air_754ae581ad80cc9f  2017-03-10         6               2.0
# 249018  air_754ae581ad80cc9f  2017-03-11        25              20.0
# 249020  air_754ae581ad80cc9f  2017-03-13         6               3.0
# 249025  air_754ae581ad80cc9f  2017-03-18        39              31.0
# 249026  air_754ae581ad80cc9f  2017-03-19        59              50.0
# 249028  air_754ae581ad80cc9f  2017-03-22         4               2.0
# 249029  air_754ae581ad80cc9f  2017-03-24        50              17.0
# 249030  air_754ae581ad80cc9f  2017-03-25        54              32.0
# 249034  air_754ae581ad80cc9f  2017-03-29        18              18.0
# 249037  air_754ae581ad80cc9f  2017-04-02        16              16.0
# 249038  air_754ae581ad80cc9f  2017-04-03        32              24.0
# 249041  air_754ae581ad80cc9f  2017-04-06        28              27.0
# 249043  air_754ae581ad80cc9f  2017-04-08        42              38.0
# 249048  air_754ae581ad80cc9f  2017-04-14         3               2.0
# 249049  air_754ae581ad80cc9f  2017-04-15        39              20.0
# 249053  air_754ae581ad80cc9f  2017-04-19         6               6.0
# 249056  air_754ae581ad80cc9f  2017-04-22        47              28.0
# 249887  air_084d98859256acf0  2016-11-10        20               8.0
#
#         reserve_rate
# 1006      200.000000
# 3744        3.278689
# 3747       14.285714
# 3748       43.859649
# 3749       15.625000
# 3750       17.142857
# 3754       17.647059
# 3755       20.689655
# 3756       14.285714
# 3758       16.666667
# 3759       44.117647
# 3760       32.812500
# 3761        8.695652
# 3765       16.981132
# 3766       34.482759
# 3767        8.333333
# 3770       27.692308
# 3771       28.358209
# 3775       24.324324
# 3776       34.545455
# 3777       38.095238
# 3782       17.021277
# 3784       10.526316
# 3785       43.333333
# 3786        5.128205
# 3787       14.285714
# 3788       77.586207
# 3789       53.030303
# 3794       36.842105
# 3795       22.000000
# ...              ...
# 248996     44.444444
# 248997     61.538462
# 248998     34.375000
# 248999     56.250000
# 249001     80.000000
# 249005     14.814815
# 249006     20.000000
# 249009   1100.000000
# 249010     62.857143
# 249011     33.333333
# 249012     50.000000
# 249016     60.000000
# 249017     33.333333
# 249018     80.000000
# 249020     50.000000
# 249025     79.487179
# 249026     84.745763
# 249028     50.000000
# 249029     34.000000
# 249030     59.259259
# 249034    100.000000
# 249037    100.000000
# 249038     75.000000
# 249041     96.428571
# 249043     90.476190
# 249048     66.666667
# 249049     51.282051
# 249053    100.000000
# 249056     59.574468
# 249887     40.000000
#
# [28064 rows x 5 columns]

# %%
df4.head()
# Out:
#            hpg_store_id       visit_datetime     reserve_datetime  \
# 0  hpg_c63f6f42e088e50f  2016-01-01 11:00:00  2016-01-01 09:00:00
# 1  hpg_dac72789163a3f47  2016-01-01 13:00:00  2016-01-01 06:00:00
# 2  hpg_c8e24dcf51ca1eb5  2016-01-01 16:00:00  2016-01-01 14:00:00
# 3  hpg_24bb207e5fd49d4a  2016-01-01 17:00:00  2016-01-01 11:00:00
# 4  hpg_25291c542ebb3bc2  2016-01-01 17:00:00  2016-01-01 03:00:00
#
#    reserve_visitors
# 0                 1
# 1                 3
# 2                 2
# 3                 5
# 4                13

# %%
df4['visit_datetime'] = df4['visit_datetime'].str[:10]
df4.head()
# Out:
#            hpg_store_id visit_datetime     reserve_datetime  reserve_visitors
# 0  hpg_c63f6f42e088e50f     2016-01-01  2016-01-01 09:00:00                 1
# 1  hpg_dac72789163a3f47     2016-01-01  2016-01-01 06:00:00                 3
# 2  hpg_c8e24dcf51ca1eb5     2016-01-01  2016-01-01 14:00:00                 2
# 3  hpg_24bb207e5fd49d4a     2016-01-01  2016-01-01 11:00:00                 5
# 4  hpg_25291c542ebb3bc2     2016-01-01  2016-01-01 03:00:00                13

# %%
df4_edit = df4.rename(columns={'visit_datetime': 'visit_date'}).drop('reserve_datetime',axis=1)
df4_edit = df4_edit.groupby(['hpg_store_id','visit_date'])['reserve_visitors'].sum().reset_index()
df4_edit.head()
# Out:
#            hpg_store_id  visit_date  reserve_visitors
# 0  hpg_001112ef76b9802c  2016-02-26                 9
# 1  hpg_001112ef76b9802c  2016-03-17                 3
# 2  hpg_001112ef76b9802c  2016-03-31                 5
# 3  hpg_001112ef76b9802c  2016-04-05                13
# 4  hpg_001112ef76b9802c  2016-04-18                 9

# %%
df7.head()
# Out:
#            air_store_id          hpg_store_id
# 0  air_63b13c56b7201bd9  hpg_4bc649e72e2a239a
# 1  air_a24bf50c3e90d583  hpg_c34b496d0305a809
# 2  air_c7f78b4f3cba33ff  hpg_cd8ae0d9bbd58ff9
# 3  air_947eb2cae4f3e8f2  hpg_de24ea49dc25d6b8
# 4  air_965b2e0cf4119003  hpg_653238a84804d8e7

# %%
df4_edit = pd.merge(df4_edit,df7,on=['hpg_store_id'],how='inner')
df4_edit.head()
# Out:
#            hpg_store_id  visit_date  reserve_visitors          air_store_id
# 0  hpg_0183ec352e38903c  2016-01-09                 2  air_cbe867adcf44e14f
# 1  hpg_0183ec352e38903c  2016-01-11                 8  air_cbe867adcf44e14f
# 2  hpg_0183ec352e38903c  2016-01-14                11  air_cbe867adcf44e14f
# 3  hpg_0183ec352e38903c  2016-01-15                 8  air_cbe867adcf44e14f
# 4  hpg_0183ec352e38903c  2016-01-18                 9  air_cbe867adcf44e14f

# %%
air_df.head()
# Out:
#            air_store_id  visit_date  visitors  reserve_visitors  reserve_rate
# 0  air_ba937bf13d40fb24  2016-01-13        25               NaN           NaN
# 1  air_ba937bf13d40fb24  2016-01-14        32               NaN           NaN
# 2  air_ba937bf13d40fb24  2016-01-15        29               NaN           NaN
# 3  air_ba937bf13d40fb24  2016-01-16        22               NaN           NaN
# 4  air_ba937bf13d40fb24  2016-01-18         6               NaN           NaN

# %%
air_df2 = pd.merge(air_df,df4_edit,on=['air_store_id','visit_date'],how='left')
air_df2.head()
# Out:
#            air_store_id  visit_date  visitors  reserve_visitors_x  \
# 0  air_ba937bf13d40fb24  2016-01-13        25                 NaN
# 1  air_ba937bf13d40fb24  2016-01-14        32                 NaN
# 2  air_ba937bf13d40fb24  2016-01-15        29                 NaN
# 3  air_ba937bf13d40fb24  2016-01-16        22                 NaN
# 4  air_ba937bf13d40fb24  2016-01-18         6                 NaN
#
#    reserve_rate hpg_store_id  reserve_visitors_y
# 0           NaN          NaN                 NaN
# 1           NaN          NaN                 NaN
# 2           NaN          NaN                 NaN
# 3           NaN          NaN                 NaN
# 4           NaN          NaN                 NaN

# %%
airx_df = DataFrame(air_df2, columns=['air_store_id','hpg_store_id','visit_date','visitors','reserve_visitors','reserve_visitors_x','reserve_visitors_y','reserve_rate'])
airx_df['reserve_visitors'] = airx_df['reserve_visitors_x'] + airx_df['reserve_visitors_y']
airx_df['reserve_rate'] = airx_df['reserve_visitors'] / air_df['visitors'] * 100
airx_df.head()

airx_df[airx_df['reserve_rate'] > 0]
# Out:
#                 air_store_id          hpg_store_id  visit_date  visitors  \
# 4669    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-10-27        48
# 4670    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-10-28        25
# 4671    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-10-29        42
# 4673    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-01        76
# 4676    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-04         5
# 4677    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-05        51
# 4678    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-07         9
# 4688    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-19        66
# 4690    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-22         7
# 4691    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-23        36
# 4692    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-24        25
# 4693    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-25        19
# 4695    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-28        17
# 4696    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-11-29        17
# 4699    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-02         8
# 4704    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-09        39
# 4705    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-10        51
# 4707    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-12        23
# 4708    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-13        23
# 4710    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-16        18
# 4711    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-17        56
# 4712    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-19         9
# 4714    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-22        70
# 4715    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-23        18
# 4716    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-24        24
# 4717    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-26        37
# 4718    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-27        14
# 4719    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-28        67
# 4720    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-29        30
# 4721    air_3e93f3c81008696d  hpg_c2a8494d55fafbd6  2016-12-30        27
# ...                      ...                   ...         ...       ...
# 248955  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2016-12-28        16
# 248963  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-01-07         7
# 248973  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-01-18         2
# 248976  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-01-21        30
# 248978  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-01-23         7
# 248983  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-01-30         8
# 248986  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-04        16
# 248990  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-09        10
# 248991  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-10        12
# 248993  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-13        22
# 248995  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-15        24
# 248996  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-16        36
# 248997  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-17        13
# 248998  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-18        32
# 248999  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-19        32
# 249006  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-02-27        20
# 249009  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-02         1
# 249010  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-03        35
# 249011  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-04        15
# 249016  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-09        10
# 249018  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-11        25
# 249020  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-13         6
# 249025  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-18        39
# 249030  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-25        54
# 249034  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-03-29        18
# 249041  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-04-06        28
# 249043  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-04-08        42
# 249048  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-04-14         3
# 249049  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-04-15        39
# 249053  air_754ae581ad80cc9f  hpg_625efd16f722d4f4  2017-04-19         6
#
#         reserve_visitors  reserve_visitors_x  reserve_visitors_y  reserve_rate
# 4669                14.0                12.0                 2.0     29.166667
# 4670                 6.0                 4.0                 2.0     24.000000
# 4671                45.0                17.0                28.0    107.142857
# 4673                77.0                74.0                 3.0    101.315789
# 4676                18.0                11.0                 7.0    360.000000
# 4677                38.0                26.0                12.0     74.509804
# 4678                 4.0                 2.0                 2.0     44.444444
# 4688                22.0                13.0                 9.0     33.333333
# 4690                17.0                13.0                 4.0    242.857143
# 4691                17.0                15.0                 2.0     47.222222
# 4692                12.0                10.0                 2.0     48.000000
# 4693                19.0                15.0                 4.0    100.000000
# 4695                 6.0                 4.0                 2.0     35.294118
# 4696                19.0                12.0                 7.0    111.764706
# 4699                22.0                14.0                 8.0    275.000000
# 4704                48.0                39.0                 9.0    123.076923
# 4705                21.0                13.0                 8.0     41.176471
# 4707                 6.0                 4.0                 2.0     26.086957
# 4708                10.0                 7.0                 3.0     43.478261
# 4710                39.0                19.0                20.0    216.666667
# 4711                45.0                22.0                23.0     80.357143
# 4712                22.0                20.0                 2.0    244.444444
# 4714                64.0                45.0                19.0     91.428571
# 4715                60.0                58.0                 2.0    333.333333
# 4716                30.0                20.0                10.0    125.000000
# 4717                22.0                20.0                 2.0     59.459459
# 4718                30.0                25.0                 5.0    214.285714
# 4719                28.0                26.0                 2.0     41.791045
# 4720                29.0                24.0                 5.0     96.666667
# 4721                29.0                24.0                 5.0    107.407407
# ...                  ...                 ...                 ...           ...
# 248955               4.0                 2.0                 2.0     25.000000
# 248963              11.0                 7.0                 4.0    157.142857
# 248973               4.0                 2.0                 2.0    200.000000
# 248976              30.0                12.0                18.0    100.000000
# 248978              14.0                 7.0                 7.0    200.000000
# 248983              16.0                 8.0                 8.0    200.000000
# 248986              11.0                 9.0                 2.0     68.750000
# 248990               6.0                 3.0                 3.0     60.000000
# 248991               6.0                 3.0                 3.0     50.000000
# 248993              20.0                10.0                10.0     90.909091
# 248995              25.0                20.0                 5.0    104.166667
# 248996              29.0                16.0                13.0     80.555556
# 248997              16.0                 8.0                 8.0    123.076923
# 248998              13.0                11.0                 2.0     40.625000
# 248999              24.0                18.0                 6.0     75.000000
# 249006               8.0                 4.0                 4.0     40.000000
# 249009              22.0                11.0                11.0   2200.000000
# 249010              39.0                22.0                17.0    111.428571
# 249011              10.0                 5.0                 5.0     66.666667
# 249016              12.0                 6.0                 6.0    120.000000
# 249018              23.0                20.0                 3.0     92.000000
# 249020               6.0                 3.0                 3.0    100.000000
# 249025              35.0                31.0                 4.0     89.743590
# 249030              53.0                32.0                21.0     98.148148
# 249034              36.0                18.0                18.0    200.000000
# 249041              54.0                27.0                27.0    192.857143
# 249043              62.0                38.0                24.0    147.619048
# 249048               4.0                 2.0                 2.0    133.333333
# 249049              40.0                20.0                20.0    102.564103
# 249053              12.0                 6.0                 6.0    200.000000
#
# [5916 rows x 8 columns]

# %%
airx_df = airx_df.rename(columns={'reserve_visitors_x': 'reserve_visitors_air', 'reserve_visitors_y': 'reserve_visitors_hpg'})

# %%
airx_df.head()
# Out:
#            air_store_id hpg_store_id  visit_date  visitors  reserve_visitors  \
# 0  air_ba937bf13d40fb24          NaN  2016-01-13        25               NaN
# 1  air_ba937bf13d40fb24          NaN  2016-01-14        32               NaN
# 2  air_ba937bf13d40fb24          NaN  2016-01-15        29               NaN
# 3  air_ba937bf13d40fb24          NaN  2016-01-16        22               NaN
# 4  air_ba937bf13d40fb24          NaN  2016-01-18         6               NaN
#
#    reserve_visitors_air  reserve_visitors_hpg  reserve_rate
# 0                   NaN                   NaN           NaN
# 1                   NaN                   NaN           NaN
# 2                   NaN                   NaN           NaN
# 3                   NaN                   NaN           NaN
# 4                   NaN                   NaN           NaN

# %%
airxx_df = pd.merge(airx_df,df2,on=['air_store_id'],how='left')
airxx_df.head()
# Out:
#            air_store_id hpg_store_id  visit_date  visitors  reserve_visitors  \
# 0  air_ba937bf13d40fb24          NaN  2016-01-13        25               NaN
# 1  air_ba937bf13d40fb24          NaN  2016-01-14        32               NaN
# 2  air_ba937bf13d40fb24          NaN  2016-01-15        29               NaN
# 3  air_ba937bf13d40fb24          NaN  2016-01-16        22               NaN
# 4  air_ba937bf13d40fb24          NaN  2016-01-18         6               NaN
#
#    reserve_visitors_air  reserve_visitors_hpg  reserve_rate air_genre_name  \
# 0                   NaN                   NaN           NaN     Dining bar
# 1                   NaN                   NaN           NaN     Dining bar
# 2                   NaN                   NaN           NaN     Dining bar
# 3                   NaN                   NaN           NaN     Dining bar
# 4                   NaN                   NaN           NaN     Dining bar
#
#                   air_area_name   latitude   longitude
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599

# %%
airxx_df[airxx_df['reserve_visitors_air'] == 'NaN']
# Out:
# /Users/tanakayuto/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pandas/core/ops.py:714: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-d6e638d150b0> in <module>()
# ----> 1 airxx_df[airxx_df['reserve_visitors_air'] == 'NaN']
#
# /Users/tanakayuto/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     759                 other = np.asarray(other)
#     760
# --> 761             res = na_op(values, other)
#     762             if isscalar(res):
#     763                 raise TypeError('Could not compare %s type with Series' %
#
# /Users/tanakayuto/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     714                 result = getattr(x, name)(y)
#     715                 if result is NotImplemented:
# --> 716                     raise TypeError("invalid type comparison")
#     717             except AttributeError:
#     718                 result = op(x, y)
#
# TypeError: invalid type comparison

# %%
airxxx_df = pd.merge(airxx_df,df5,on=['hpg_store_id'],how='left')
airxxx_df.head()
# Out:
#            air_store_id hpg_store_id  visit_date  visitors  reserve_visitors  \
# 0  air_ba937bf13d40fb24          NaN  2016-01-13        25               NaN
# 1  air_ba937bf13d40fb24          NaN  2016-01-14        32               NaN
# 2  air_ba937bf13d40fb24          NaN  2016-01-15        29               NaN
# 3  air_ba937bf13d40fb24          NaN  2016-01-16        22               NaN
# 4  air_ba937bf13d40fb24          NaN  2016-01-18         6               NaN
#
#    reserve_visitors_air  reserve_visitors_hpg  reserve_rate air_genre_name  \
# 0                   NaN                   NaN           NaN     Dining bar
# 1                   NaN                   NaN           NaN     Dining bar
# 2                   NaN                   NaN           NaN     Dining bar
# 3                   NaN                   NaN           NaN     Dining bar
# 4                   NaN                   NaN           NaN     Dining bar
#
#                   air_area_name  latitude_x  longitude_x hpg_genre_name  \
# 0  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
# 1  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
# 2  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
# 3  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
# 4  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
#
#   hpg_area_name  latitude_y  longitude_y
# 0           NaN         NaN          NaN
# 1           NaN         NaN          NaN
# 2           NaN         NaN          NaN
# 3           NaN         NaN          NaN
# 4           NaN         NaN          NaN

# %%
airxxx_df[airxxx_df['hpg_store_id'] == 'hpg_0183ec352e38903c']
# Out:
#                 air_store_id          hpg_store_id  visit_date  visitors  \
# 113521  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-03-04        56
# 113526  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-03-10        40
# 113527  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-03-11        32
# 113532  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-03-17        68
# 113533  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-03-18        22
# 113534  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-03-19        29
# 113538  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-03-24        34
# 113539  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-03-25        38
# 113554  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-04-11         2
# 113557  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-04-14        30
# 113562  air_cbe867adcf44e14f  hpg_0183ec352e38903c  2017-04-20        12
#
#         reserve_visitors  reserve_visitors_air  reserve_visitors_hpg  \
# 113521              39.0                  34.0                   5.0
# 113526              14.0                  10.0                   4.0
# 113527              31.0                  28.0                   3.0
# 113532              48.0                  41.0                   7.0
# 113533              16.0                  13.0                   3.0
# 113534              10.0                   3.0                   7.0
# 113538              27.0                  24.0                   3.0
# 113539              42.0                  36.0                   6.0
# 113554               4.0                   2.0                   2.0
# 113557              26.0                  20.0                   6.0
# 113562              12.0                   6.0                   6.0
#
#         reserve_rate air_genre_name                    air_area_name  \
# 113521     69.642857        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113526     35.000000        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113527     96.875000        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113532     70.588235        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113533     72.727273        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113534     34.482759        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113538     79.411765        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113539    110.526316        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113554    200.000000        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113557     86.666667        Izakaya  Fukuoka-ken Kitakyūshū-shi None
# 113562    100.000000        Izakaya  Fukuoka-ken Kitakyūshū-shi None
#
#         latitude_x  longitude_x hpg_genre_name  \
# 113521   33.866465   130.764923       Creation
# 113526   33.866465   130.764923       Creation
# 113527   33.866465   130.764923       Creation
# 113532   33.866465   130.764923       Creation
# 113533   33.866465   130.764923       Creation
# 113534   33.866465   130.764923       Creation
# 113538   33.866465   130.764923       Creation
# 113539   33.866465   130.764923       Creation
# 113554   33.866465   130.764923       Creation
# 113557   33.866465   130.764923       Creation
# 113562   33.866465   130.764923       Creation
#
#                             hpg_area_name  latitude_y  longitude_y
# 113521  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113526  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113527  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113532  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113533  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113534  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113538  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113539  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113554  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113557  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425
# 113562  Fukuoka-ken Kitakyūshū-shi Aoyama    33.86184   130.751425

# %%
df6.head()
# Out:
#   calendar_date day_of_week  holiday_flg
# 0    2016-01-01      Friday            1
# 1    2016-01-02    Saturday            1
# 2    2016-01-03      Sunday            1
# 3    2016-01-04      Monday            0
# 4    2016-01-05     Tuesday            0

# %%
df6_edit = df6.rename(columns={'calendar_date': 'visit_date'})
airxxxx_df = pd.merge(airxxx_df,df6_edit,on=['visit_date'],how='left')
airxxxx_df.head()
# Out:
#            air_store_id hpg_store_id  visit_date  visitors  reserve_visitors  \
# 0  air_ba937bf13d40fb24          NaN  2016-01-13        25               NaN
# 1  air_ba937bf13d40fb24          NaN  2016-01-14        32               NaN
# 2  air_ba937bf13d40fb24          NaN  2016-01-15        29               NaN
# 3  air_ba937bf13d40fb24          NaN  2016-01-16        22               NaN
# 4  air_ba937bf13d40fb24          NaN  2016-01-18         6               NaN
#
#    reserve_visitors_air  reserve_visitors_hpg  reserve_rate air_genre_name  \
# 0                   NaN                   NaN           NaN     Dining bar
# 1                   NaN                   NaN           NaN     Dining bar
# 2                   NaN                   NaN           NaN     Dining bar
# 3                   NaN                   NaN           NaN     Dining bar
# 4                   NaN                   NaN           NaN     Dining bar
#
#                   air_area_name  latitude_x  longitude_x hpg_genre_name  \
# 0  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
# 1  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
# 2  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
# 3  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
# 4  Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599            NaN
#
#   hpg_area_name  latitude_y  longitude_y day_of_week  holiday_flg
# 0           NaN         NaN          NaN   Wednesday            0
# 1           NaN         NaN          NaN    Thursday            0
# 2           NaN         NaN          NaN      Friday            0
# 3           NaN         NaN          NaN    Saturday            0
# 4           NaN         NaN          NaN      Monday            0

# %% [markdown]
# # 残りのやること
# - 結合プロセスを綺麗にする
# - 店舗情報をマッピングして一元化する

# %% [markdown]
# df2
# df5
# df7

# %%
df_check = pd.merge(df2,df7,on=['air_store_id'],how='inner')
df_check.head()
# Out:
#            air_store_id  air_genre_name                   air_area_name  \
# 0  air_7cc17a324ae5c7dc  Italian/French    Hyōgo-ken Kōbe-shi Kumoidōri
# 1  air_290e7a57b390f78e  Italian/French    Tōkyō-to Minato-ku Shibakōen
# 2  air_638c35eb25e53eea  Italian/French  Fukuoka-ken Fukuoka-shi Daimyō
# 3  air_fcfbdcf7b1f82c6e  Italian/French     Tōkyō-to Shibuya-ku Shibuya
# 4  air_f8233ad00755c35c  Italian/French     Tōkyō-to Shibuya-ku Shibuya
#
#     latitude   longitude          hpg_store_id
# 0  34.695124  135.197852  hpg_9b38b9e13da6da27
# 1  35.658068  139.751599  hpg_c5ec63f52e4a7e9e
# 2  33.589216  130.392813  hpg_f07ec7b288165b27
# 3  35.661777  139.704051  hpg_0b53e00789c2eafe
# 4  35.661777  139.704051  hpg_098e4dd30e54fee6

# %%
df_check2 = pd.merge(df_check,df5,on=['hpg_store_id'],how='left')
df_check2.head()
# Out:
#            air_store_id  air_genre_name                   air_area_name  \
# 0  air_7cc17a324ae5c7dc  Italian/French    Hyōgo-ken Kōbe-shi Kumoidōri
# 1  air_290e7a57b390f78e  Italian/French    Tōkyō-to Minato-ku Shibakōen
# 2  air_638c35eb25e53eea  Italian/French  Fukuoka-ken Fukuoka-shi Daimyō
# 3  air_fcfbdcf7b1f82c6e  Italian/French     Tōkyō-to Shibuya-ku Shibuya
# 4  air_f8233ad00755c35c  Italian/French     Tōkyō-to Shibuya-ku Shibuya
#
#    latitude_x  longitude_x          hpg_store_id         hpg_genre_name  \
# 0   34.695124   135.197852  hpg_9b38b9e13da6da27                    NaN
# 1   35.658068   139.751599  hpg_c5ec63f52e4a7e9e                    NaN
# 2   33.589216   130.392813  hpg_f07ec7b288165b27  Spain Bar/Italian Bar
# 3   35.661777   139.704051  hpg_0b53e00789c2eafe                Italian
# 4   35.661777   139.704051  hpg_098e4dd30e54fee6  Spain Bar/Italian Bar
#
#                     hpg_area_name  latitude_y  longitude_y
# 0                             NaN         NaN          NaN
# 1                             NaN         NaN          NaN
# 2  Fukuoka-ken Fukuoka-shi Daimyō   33.586969   130.392801
# 3        Tōkyō-to Shibuya-ku None   35.659214   139.699736
# 4        Tōkyō-to Shibuya-ku None   35.659214   139.699736

# %%
df_check3 = DataFrame(df_check2, columns=['air_genre_name','hpg_genre_name'])
df_check3 = df_check3.drop_duplicates(['air_genre_name','hpg_genre_name'])
df_check3
# Out:
#                    air_genre_name                hpg_genre_name
# 0                  Italian/French                           NaN
# 2                  Italian/French         Spain Bar/Italian Bar
# 3                  Italian/French                       Italian
# 20                     Dining bar                           NaN
# 24                     Dining bar                       Seafood
# 27                     Dining bar                       Italian
# 28                     Dining bar         International cuisine
# 29                     Dining bar                      Creation
# 30                     Dining bar         Spain Bar/Italian Bar
# 45           Yakiniku/Korean food                  Grilled meat
# 46           Yakiniku/Korean food                           NaN
# 49           Yakiniku/Korean food                Japanese style
# 54                    Cafe/Sweets                           NaN
# 58                        Izakaya                           NaN
# 59                        Izakaya                       Seafood
# 61                        Izakaya                Japanese style
# 75                        Izakaya         Spain Bar/Italian Bar
# 76                        Izakaya        Creative Japanese food
# 80                        Izakaya         International cuisine
# 82                        Izakaya                      Creation
# 121  Okonomiyaki/Monja/Teppanyaki                           NaN
# 122  Okonomiyaki/Monja/Teppanyaki  Okonomiyaki/Monja/Teppanyaki
# 127                  Bar/Cocktail                           NaN
# 128                  Bar/Cocktail         International cuisine
# 129                  Bar/Cocktail                       Karaoke
# 132                  Bar/Cocktail                          Cafe
# 134                  Bar/Cocktail                 Amusement bar
# 135                 Japanese food                Japanese style
# 137                 Japanese food                           NaN
# 139                 Japanese food      Japanese cuisine/Kaiseki
# 141                 Japanese food      Japanese food in general
# 142              Creative cuisine                           NaN
# 144                         Other                           NaN
# 145                  Western food                           NaN
# 147                  Western food         Steak/Hamburger/Curry
# 149                 Karaoke/Party                         Party

# %% [markdown]
# マッピングはかなりバラつくのであんま意味なし。
# airのジャンルで統一する
